# %%
## this cell is for development debug only
import repackage
repackage.add_path('/home/danial/code/pyscpi/')
# Out:
# '/home/danial/code/pyscpi'

# %%
from pyscpi import scpi
from pyscpi.keysight import osc

inst = scpi.Instrument('192.168.178.50', 5025)

print(inst.query('*IDN?'))
# Out:
# KEYSIGHT TECHNOLOGIES,DSOX1202G,CN61444379,02.12.2021071625

# %%
time, allData = osc.readSingleChannel(inst, 1, debug=True)
# Out:
# ['+0', '+0', '+1000000', '+1', '+5.00000000E-010', '-2.50063632E-004', '+0', '+8.04020100E-003', '-1.50000000E-004', '+128\n']
# Reading data
# 01000000

# %%
#time, allData = osc.readChannels(inst, [1], debug=True)

# %%
#https://matplotlib.org/ipympl/#
# %matplotlib ipympl
import matplotlib.pyplot as plt
import numpy as np

plt.plot(time, allData)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
